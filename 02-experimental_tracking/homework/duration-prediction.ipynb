# %%
import pandas as pd

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.metrics import root_mean_squared_error

# %%
import mlflow 
mlflow.set_tracking_uri("sqlite:///mlruns.db")
mlflow.set_experiment('nyc-taxi-experiment')
# Out:
# <Experiment: artifact_location='/Users/kpedido/code/learning_projects/mlops/2_experimental_tracking/mlruns/1', creation_time=1748290853483, experiment_id='1', last_update_time=1748290853483, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df_original = pd.read_parquet(filename)

    df_original['duration'] = (df_original.tpep_dropoff_datetime - df_original.tpep_pickup_datetime)
    df_original['duration'] = df_original.duration.dt.total_seconds()/60

    df = df_original[(df_original.duration >= 1) & (df_original.duration <= 60) ]
    return df

# %%
train_df = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet')
val_df = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet')

# %%
train_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# 5               1  2021-01-01 00:16:29   2021-01-01 00:24:30              1.0
# ...           ...                  ...                   ...              ...
# 1369763         2  2021-01-31 23:04:00   2021-01-31 23:18:00              NaN
# 1369764         2  2021-01-31 23:03:00   2021-01-31 23:33:00              NaN
# 1369765         2  2021-01-31 23:29:00   2021-01-31 23:51:00              NaN
# 1369766         2  2021-01-31 23:25:00   2021-01-31 23:38:00              NaN
# 1369768         2  2021-01-31 23:08:29   2021-01-31 23:31:22              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.10         1.0                  N           142
# 2                14.70         1.0                  N           132
# 3                10.60         1.0                  N           138
# 4                 4.94         1.0                  N            68
# 5                 1.60         1.0                  N           224
# ...                ...         ...                ...           ...
# 1369763           7.74         NaN               None           159
# 1369764           8.89         NaN               None           229
# 1369765           7.43         NaN               None            41
# 1369766           6.26         NaN               None            74
# 1369768           4.68         NaN               None            89
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  43             2         8.00   3.00      0.5        0.00
# 2                 165             1        42.00   0.50      0.5        8.65
# 3                 132             1        29.00   0.50      0.5        6.05
# 4                  33             1        16.50   0.50      0.5        4.06
# 5                  68             1         8.00   3.00      0.5        2.35
# ...               ...           ...          ...    ...      ...         ...
# 1369763           259             0        22.15   0.00      0.5        0.00
# 1369764           181             0        27.78   0.00      0.5        7.46
# 1369765            70             0        32.58   0.00      0.5        0.00
# 1369766           137             0        16.85   0.00      0.5        3.90
# 1369768            61             0        25.45   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         11.80
# 2                0.00                    0.3         51.95
# 3                0.00                    0.3         36.35
# 4                0.00                    0.3         24.36
# 5                0.00                    0.3         14.15
# ...               ...                    ...           ...
# 1369763          0.00                    0.3         22.95
# 1369764          0.00                    0.3         38.54
# 1369765          6.12                    0.3         39.50
# 1369766          0.00                    0.3         24.05
# 1369768          0.00                    0.3         29.00
#
#          congestion_surcharge  airport_fee   duration
# 0                         2.5          NaN   6.033333
# 2                         0.0          NaN  27.600000
# 3                         0.0          NaN  15.216667
# 4                         2.5          NaN  16.533333
# 5                         2.5          NaN   8.016667
# ...                       ...          ...        ...
# 1369763                   NaN          NaN  14.000000
# 1369764                   NaN          NaN  30.000000
# 1369765                   NaN          NaN  22.000000
# 1369766                   NaN          NaN  13.000000
# 1369768                   NaN          NaN  22.883333
#
# [1343254 rows x 20 columns]

# %%
val_df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-02-01 00:40:47   2021-02-01 00:48:28              1.0
# 1               1  2021-02-01 00:07:44   2021-02-01 00:20:31              1.0
# 2               1  2021-02-01 00:59:36   2021-02-01 01:24:13              1.0
# 3               2  2021-02-01 00:03:26   2021-02-01 00:16:32              1.0
# 4               2  2021-02-01 00:20:20   2021-02-01 00:24:03              2.0
# ...           ...                  ...                   ...              ...
# 1371703         2  2021-02-28 23:25:41   2021-02-28 23:42:35              NaN
# 1371705         2  2021-02-28 23:27:00   2021-02-28 23:41:00              NaN
# 1371706         2  2021-02-28 23:18:05   2021-02-28 23:26:48              NaN
# 1371707         2  2021-02-28 23:41:07   2021-03-01 00:13:44              NaN
# 1371708         2  2021-02-28 23:04:15   2021-02-28 23:33:17              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 2.30         1.0                  N           141
# 1                 1.60         1.0                  N            43
# 2                 5.30         1.0                  N           114
# 3                 2.79         1.0                  N           236
# 4                 0.64         1.0                  N           229
# ...                ...         ...                ...           ...
# 1371703           8.84         NaN               None           141
# 1371705           4.42         NaN               None            68
# 1371706           1.50         NaN               None            68
# 1371707          15.30         NaN               None           113
# 1371708          12.73         NaN               None           226
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 226             2         8.50   3.00      0.5        0.00
# 1                 263             2         9.50   3.00      0.5        0.00
# 2                 263             2        19.00   3.00      0.5        0.00
# 3                 229             1        11.00   0.50      0.5        2.96
# 4                 140             1         4.50   0.50      0.5        1.66
# ...               ...           ...          ...    ...      ...         ...
# 1371703           160             0        36.83   2.75      0.5        0.00
# 1371705            24             0        17.14   0.00      0.5        4.33
# 1371706           137             0         9.46   0.00      0.5        2.64
# 1371707           254             0        59.15   2.75      0.5        0.00
# 1371708            10             0        44.62   2.75      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         12.30
# 1                0.00                    0.3         13.30
# 2                0.00                    0.3         22.80
# 3                0.00                    0.3         17.76
# 4                0.00                    0.3          9.96
# ...               ...                    ...           ...
# 1371703          6.12                    0.3         46.50
# 1371705          0.00                    0.3         24.77
# 1371706          0.00                    0.3         15.40
# 1371707          0.00                    0.3         62.70
# 1371708          0.00                    0.3         48.17
#
#          congestion_surcharge  airport_fee   duration
# 0                         2.5          NaN   7.683333
# 1                         0.0          NaN  12.783333
# 2                         2.5          NaN  24.616667
# 3                         2.5          NaN  13.100000
# 4                         2.5          NaN   3.716667
# ...                       ...          ...        ...
# 1371703                   NaN          NaN  16.900000
# 1371705                   NaN          NaN  14.000000
# 1371706                   NaN          NaN   8.716667
# 1371707                   NaN          NaN  32.616667
# 1371708                   NaN          NaN  29.033333
#
# [1340859 rows x 20 columns]

# %%
dv = DictVectorizer()

# %%
categorical = ['PULocationID', 'DOLocationID']
train_df.loc[:, categorical] = train_df[categorical].astype(str)
val_df.loc[:, categorical] = val_df[categorical].astype(str)
# Out:
# /var/folders/8m/f09cj82x26d0q8dkstjrlqjh0000gn/T/ipykernel_65495/1761831974.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['142' '132' '138' ... '41' '74' '89']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[:, categorical] = train_df[categorical].astype(str)
# /var/folders/8m/f09cj82x26d0q8dkstjrlqjh0000gn/T/ipykernel_65495/1761831974.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['43' '165' '132' ... '70' '137' '61']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   train_df.loc[:, categorical] = train_df[categorical].astype(str)
# /var/folders/8m/f09cj82x26d0q8dkstjrlqjh0000gn/T/ipykernel_65495/1761831974.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['141' '43' '114' ... '68' '113' '226']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   val_df.loc[:, categorical] = val_df[categorical].astype(str)
# /var/folders/8m/f09cj82x26d0q8dkstjrlqjh0000gn/T/ipykernel_65495/1761831974.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['226' '263' '263' ... '137' '254' '10']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   val_df.loc[:, categorical] = val_df[categorical].astype(str)

# %%
train_df[categorical]
# Out:
#         PULocationID DOLocationID
# 0                142           43
# 2                132          165
# 3                138          132
# 4                 68           33
# 5                224           68
# ...              ...          ...
# 1369763          159          259
# 1369764          229          181
# 1369765           41           70
# 1369766           74          137
# 1369768           89           61
#
# [1343254 rows x 2 columns]

# %%
train_df_dicts = train_df[categorical].to_dict(orient='records')
val_df_dicts = val_df[categorical].to_dict(orient='records')

# %%
X_train = dv.fit_transform(train_df_dicts)
X_val = dv.fit_transform(val_df_dicts)

# %%
X_val
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2681718 stored elements and shape (1340859, 518)>

# %%
target = 'duration'
y_train = train_df[target].values
y_val = val_df[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)
y_pred
# Out:
# array([ 9.44083611, 36.29019304, 30.528434  , ..., 13.56182908,
#         8.89576656, 26.79785254], shape=(1343254,))

# %%
root_mean_squared_error(y_train, y_pred)
# Out:
# 6.845620258734961

# %%
y_val_pred = lr.predict(X_val)
y_val_pred
# Out:
# array([17.41505208,  9.51166177,  9.01375596, ..., 10.14819727,
#        29.05628312, 12.89625376], shape=(1340859,))

# %%
root_mean_squared_error(y_val, y_val_pred)
# Out:
# 7.737370478957588

# %%
with mlflow.start_run():

    mlflow.set_tag('developer', 'kpedido')

    mlflow.log_param('training-data-path', 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet')
    mlflow.log_param('valid-data-path', 'https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet')


    
    alpha = 0.01 
    mlflow.log_param('alpha', alpha)

    lr= Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = root_mean_squared_error(y_val, y_pred)

    mlflow.log_metric('rmse', rmse)

# %%
df = pd.read_parquet('../data/yellow_tripdata_2023-01.parquet')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          9.3   1.00      0.5        0.00           0.0
# 1             1          7.9   1.00      0.5        4.00           0.0
# 2             1         14.9   1.00      0.5       15.00           0.0
# 3             1         12.1   7.25      0.5        0.00           0.0
# 4             1         11.4   1.00      0.5        3.28           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    1.0         14.30                   2.5         0.00
# 1                    1.0         16.90                   2.5         0.00
# 2                    1.0         34.90                   2.5         0.00
# 3                    1.0         20.85                   0.0         1.25
# 4                    1.0         19.68                   2.5         0.00

# %%
import xgboost as xgb 

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)

        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, "validation")],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)

# %%
params = {
    'learning_rate': 0.6550522874897998,
    'max_depth': 9,
    'min_child_weight': 11.828925955992666,
    'objective': 'reg:linear',
    'reg_alpha': 0.07066490658263495,
    'reg_lambda': 0.0025742386226546544,
    'seed': 42
}

mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=1000,
    evals=[(valid, "validation")],
    early_stopping_rounds=50
)
# Out:
# 2025/05/27 00:24:17 WARNING mlflow.utils.autologging_utils: MLflow xgboost autologging is known to be compatible with 1.4.2 <= xgboost <= 3.0.0, but the installed version is 3.0.2. If you encounter errors during autologging, try upgrading / downgrading xgboost to a compatible version, or try upgrading MLflow.
# 2025/05/27 00:24:17 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8f1d6883c2cc475e8928d9708a12935b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:8.83639
# [1]	validation-rmse:8.63831
# [2]	validation-rmse:8.52618
# [3]	validation-rmse:8.40978
# /opt/anaconda3/envs/ml/lib/python3.13/site-packages/xgboost/callback.py:386: UserWarning: [00:24:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [4]	validation-rmse:8.32388
# [5]	validation-rmse:8.20999
# [6]	validation-rmse:8.13036
# [7]	validation-rmse:8.08000
# [8]	validation-rmse:8.02366
# [9]	validation-rmse:7.94534
# [10]	validation-rmse:7.88295
# [11]	validation-rmse:7.83271
# [12]	validation-rmse:7.79073
# [13]	validation-rmse:7.73679
# [14]	validation-rmse:7.69474
# [15]	validation-rmse:7.66687
# [16]	validation-rmse:7.63036
# [17]	validation-rmse:7.59969
# [18]	validation-rmse:7.57757
# [19]	validation-rmse:7.54034
# [20]	validation-rmse:7.50038
# [21]	validation-rmse:7.54781
# [22]	validation-rmse:7.52858
# [23]	validation-rmse:7.50885
# [24]	validation-rmse:7.47057
# [25]	validation-rmse:7.43300
# [26]	validation-rmse:7.41902
# [27]	validation-rmse:7.40324
# [28]	validation-rmse:7.37875
# [29]	validation-rmse:7.36291
# [30]	validation-rmse:7.35454
# [31]	validation-rmse:7.33977
# [32]	validation-rmse:7.31394
# [33]	validation-rmse:7.27978
# [34]	validation-rmse:7.27215
# [35]	validation-rmse:7.26343
# [36]	validation-rmse:7.24669
# [37]	validation-rmse:7.22456
# [38]	validation-rmse:7.23947
# [39]	validation-rmse:7.22546
# [40]	validation-rmse:7.21973
# [41]	validation-rmse:7.28584
# [42]	validation-rmse:7.27448
# [43]	validation-rmse:7.27390
# [44]	validation-rmse:7.26757
# [45]	validation-rmse:7.25232
# [46]	validation-rmse:7.23340
# [47]	validation-rmse:7.24490
# [48]	validation-rmse:7.24089
# [49]	validation-rmse:7.23540
# [50]	validation-rmse:7.22807
# [51]	validation-rmse:7.20860
# [52]	validation-rmse:7.20212
# [53]	validation-rmse:7.19816
# [54]	validation-rmse:7.18837
# [55]	validation-rmse:7.18592
# [56]	validation-rmse:7.17928
# [57]	validation-rmse:7.17509
# [58]	validation-rmse:7.16624
# [59]	validation-rmse:7.15605
# [60]	validation-rmse:7.15389
# [61]	validation-rmse:7.15372
# [62]	validation-rmse:7.14998
# [63]	validation-rmse:7.14525
# [64]	validation-rmse:7.14383
# [65]	validation-rmse:7.14130
# [66]	validation-rmse:7.12537
# [67]	validation-rmse:7.10077
# [68]	validation-rmse:7.10088
# [69]	validation-rmse:7.08540
# [70]	validation-rmse:7.08154
# [71]	validation-rmse:7.08243
# [72]	validation-rmse:7.07611
# [73]	validation-rmse:7.06933
# [74]	validation-rmse:7.06942
# [75]	validation-rmse:7.05714
# [76]	validation-rmse:7.05951
# [77]	validation-rmse:7.02099
# [78]	validation-rmse:7.01826
# [79]	validation-rmse:7.01573
# [80]	validation-rmse:7.01212
# [81]	validation-rmse:7.00945
# [82]	validation-rmse:7.00808
# [83]	validation-rmse:7.00531
# [84]	validation-rmse:7.00364
# [85]	validation-rmse:7.00390
# [86]	validation-rmse:7.00356
# [87]	validation-rmse:6.99718
# [88]	validation-rmse:6.99360
# [89]	validation-rmse:6.97645
# [90]	validation-rmse:6.96254
# [91]	validation-rmse:6.95119
# [92]	validation-rmse:6.93477
# [93]	validation-rmse:6.92886
# [94]	validation-rmse:6.92330
# [95]	validation-rmse:6.92157
# [96]	validation-rmse:6.92025
# [97]	validation-rmse:6.90771
# [98]	validation-rmse:6.90345
# [99]	validation-rmse:6.89650
# [100]	validation-rmse:6.89214
# [101]	validation-rmse:6.88151
# [102]	validation-rmse:6.87186
# [103]	validation-rmse:6.87037
# [104]	validation-rmse:6.86553
# [105]	validation-rmse:6.86387
# [106]	validation-rmse:6.87085
# [107]	validation-rmse:6.86989
# [108]	validation-rmse:6.86904
# [109]	validation-rmse:6.87075
# [110]	validation-rmse:6.87000
# [111]	validation-rmse:6.86833
# [112]	validation-rmse:6.86702
# [113]	validation-rmse:6.86626
# [114]	validation-rmse:6.86809
# [115]	validation-rmse:6.86810
# [116]	validation-rmse:6.86776
# [117]	validation-rmse:6.88056
# [118]	validation-rmse:6.88048
# [119]	validation-rmse:6.88172
# [120]	validation-rmse:6.89337
# [121]	validation-rmse:6.89218
# [122]	validation-rmse:6.88745
# [123]	validation-rmse:6.88647
# [124]	validation-rmse:6.88315
# [125]	validation-rmse:6.88109
# [126]	validation-rmse:6.87583
# [127]	validation-rmse:6.87460
# [128]	validation-rmse:6.86912
# [129]	validation-rmse:6.86399
# [130]	validation-rmse:6.85639
# [131]	validation-rmse:6.85236
# [132]	validation-rmse:6.85946
# [133]	validation-rmse:6.85889
# [134]	validation-rmse:6.85931
# [135]	validation-rmse:6.85884
# [136]	validation-rmse:6.85699
# [137]	validation-rmse:6.85649
# [138]	validation-rmse:6.85328
# [139]	validation-rmse:6.85008
# [140]	validation-rmse:6.84931
# [141]	validation-rmse:6.84985
# [142]	validation-rmse:6.84588
# [143]	validation-rmse:6.84344
# [144]	validation-rmse:6.84227
# [145]	validation-rmse:6.84069
# [146]	validation-rmse:6.83941
# [147]	validation-rmse:6.83808
# [148]	validation-rmse:6.83936
# [149]	validation-rmse:6.83062
# [150]	validation-rmse:6.83054
# [151]	validation-rmse:6.83010
# [152]	validation-rmse:6.82954
# [153]	validation-rmse:6.82774
# [154]	validation-rmse:6.82551
# [155]	validation-rmse:6.82085
# [156]	validation-rmse:6.81755
# [157]	validation-rmse:6.81591
# [158]	validation-rmse:6.81778
# [159]	validation-rmse:6.81387
# [160]	validation-rmse:6.81179
# [161]	validation-rmse:6.81166
# [162]	validation-rmse:6.82427
# [163]	validation-rmse:6.82417
# [164]	validation-rmse:6.82456
# [165]	validation-rmse:6.82359
# [166]	validation-rmse:6.82254
# [167]	validation-rmse:6.82221
# [168]	validation-rmse:6.80690
# [169]	validation-rmse:6.80301
# [170]	validation-rmse:6.80196
# [171]	validation-rmse:6.80191
# [172]	validation-rmse:6.80369
# [173]	validation-rmse:6.80321
# [174]	validation-rmse:6.80318
# [175]	validation-rmse:6.81068
# [176]	validation-rmse:6.81043
# [177]	validation-rmse:6.81002
# [178]	validation-rmse:6.80004
# [179]	validation-rmse:6.79989
# [180]	validation-rmse:6.80542
# [181]	validation-rmse:6.80534
# [182]	validation-rmse:6.80474
# [183]	validation-rmse:6.80503
# [184]	validation-rmse:6.80408
# [185]	validation-rmse:6.80240
# [186]	validation-rmse:6.80091
# [187]	validation-rmse:6.80100
# [188]	validation-rmse:6.80015
# [189]	validation-rmse:6.79957
# [190]	validation-rmse:6.80151
# [191]	validation-rmse:6.80042
# [192]	validation-rmse:6.80068
# [193]	validation-rmse:6.80046
# [194]	validation-rmse:6.80010
# [195]	validation-rmse:6.79982
# [196]	validation-rmse:6.81429
# [197]	validation-rmse:6.80496
# [198]	validation-rmse:6.81764
# [199]	validation-rmse:6.80696
# [200]	validation-rmse:6.80980
# [201]	validation-rmse:6.81367
# [202]	validation-rmse:6.81347
# [203]	validation-rmse:6.81335
# [204]	validation-rmse:6.81316
# [205]	validation-rmse:6.81447
# [206]	validation-rmse:6.81437
# [207]	validation-rmse:6.81435
# [208]	validation-rmse:6.81414
# [209]	validation-rmse:6.81408
# [210]	validation-rmse:6.81387
# [211]	validation-rmse:6.81369
# [212]	validation-rmse:6.81364
# [213]	validation-rmse:6.80555
# [214]	validation-rmse:6.81243
# [215]	validation-rmse:6.80525
# [216]	validation-rmse:6.80513
# [217]	validation-rmse:6.79860
# [218]	validation-rmse:6.80234
# [219]	validation-rmse:6.80157
# [220]	validation-rmse:6.80391
# [221]	validation-rmse:6.80376
# [222]	validation-rmse:6.80203
# [223]	validation-rmse:6.80202
# [224]	validation-rmse:6.80480
# [225]	validation-rmse:6.80478
# [226]	validation-rmse:6.80268
# [227]	validation-rmse:6.80862
# [228]	validation-rmse:6.80413
# [229]	validation-rmse:6.81116
# [230]	validation-rmse:6.80560
# [231]	validation-rmse:6.80541
# [232]	validation-rmse:6.79999
# [233]	validation-rmse:6.80293
# [234]	validation-rmse:6.80307
# [235]	validation-rmse:6.79957
# [236]	validation-rmse:6.79959
# [237]	validation-rmse:6.79945
# [238]	validation-rmse:6.79930
# [239]	validation-rmse:6.79931
# [240]	validation-rmse:6.79920
# [241]	validation-rmse:6.79904
# [242]	validation-rmse:6.79906
# [243]	validation-rmse:6.79899
# [244]	validation-rmse:6.79874
# [245]	validation-rmse:6.80289
# [246]	validation-rmse:6.80320
# [247]	validation-rmse:6.80268
# [248]	validation-rmse:6.80687
# [249]	validation-rmse:6.80307
# [250]	validation-rmse:6.80717
# [251]	validation-rmse:6.80349
# [252]	validation-rmse:6.81057
# [253]	validation-rmse:6.80523
# [254]	validation-rmse:6.80503
# [255]	validation-rmse:6.80497
# [256]	validation-rmse:6.79982
# [257]	validation-rmse:6.79963
# [258]	validation-rmse:6.79968
# [259]	validation-rmse:6.80576
# [260]	validation-rmse:6.80574
# [261]	validation-rmse:6.80569
# [262]	validation-rmse:6.80575
# [263]	validation-rmse:6.80540
# [264]	validation-rmse:6.80549
# [265]	validation-rmse:6.79989
# [266]	validation-rmse:6.79997
# [267]	validation-rmse:6.79985
# 2025/05/27 00:24:30 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2025/05/27 00:24:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/anaconda3/envs/ml/lib/python3.13/site-packages/mlflow/xgboost/__init__.py:168: UserWarning: [00:24:30] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2025/05/27 00:24:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
